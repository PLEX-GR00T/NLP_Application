# %% [markdown]
# <a href="https://colab.research.google.com/github/PLEX-GR00T/NLP/blob/main/Models_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Evaluation for all models.

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:.1f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:.1f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
# d = {
#     'x':    ['deepset/roberta-base-squad2', 'deepset/roberta-base-squad2',  'deepset/roberta-base-squad2', 
#              'albert-base-v2', 'albert-base-v2', 'albert-base-v2', 
#              'deepset/tinyroberta-squad2', 'deepset/tinyroberta-squad2', 'deepset/tinyroberta-squad2',
#              'deepset/roberta-large-squad2','deepset/roberta-large-squad2','deepset/roberta-large-squad2'],
#     'y':    [   82.84,    64.05,   97.71,     
#                 59.01,     48.58,   94.77,    
#                 78.29,    63.07,   97.49,    
#                 92.36,    77.88,   99.01],
#     'group':[  'F1',  'Exact_Match(EM)', 'top_4_accuracy',   
#                 'F1',  'Exact_Match(EM)',  'top_4_accuracy',   
#                 'F1',  'Exact_Match(EM)',  'top_4_accuracy',  
#                 'F1',  'Exact_Match(EM)',  'top_4_accuracy',   
#                 'F1',  'Exact_Match(EM)',  'top_4_accuracy']
# }

# %%
import matplotlib.pyplot as plt
import seaborn as sns  
import numpy as np

d = {
    'x':    ['deepset/roberta-base-squad2', 'deepset/roberta-base-squad2',  'deepset/roberta-base-squad2', 
             'distilbert-base-cased-distilled-squad', 'distilbert-base-cased-distilled-squad', 'distilbert-base-cased-distilled-squad', 
             'deepset/minilm-uncased-squad2', 'deepset/minilm-uncased-squad2', 'deepset/minilm-uncased-squad2',
             'albert-base-v2', 'albert-base-v2', 'albert-base-v2', 
             'deepset/tinyroberta-squad2', 'deepset/tinyroberta-squad2', 'deepset/tinyroberta-squad2',
             'deepset/roberta-large-squad2','deepset/roberta-large-squad2','deepset/roberta-large-squad2'],
    'y':    [   82.84,    64.05,   98.10,
                97.71,    80.63,  63.61,
                80.64,    61.25,   96.40,
                59.01,     48.58,   94.77,    
                78.29,    63.07,   97.49,    
                92.36,    77.88,   99.01],
    'group':[  'F1',  'Exact_Match(EM)', 'top_4_accuracy',
                'F1',  'Exact_Match(EM)',  'top_4_accuracy',   
                'F1',  'Exact_Match(EM)',  'top_4_accuracy',
                'F1',  'Exact_Match(EM)', 'top_4_accuracy',
                'F1',  'Exact_Match(EM)',  'top_4_accuracy',   
                'F1',  'Exact_Match(EM)',  'top_4_accuracy']
}

# sns.barplot(x='x', y='y', hue="group", data=d)


sns.set(rc={'figure.figsize':(20, 10)})
ax = sns.barplot(x='x', y='y', hue="group", data=d, palette='plasma')
ax.set(ylabel="Percentage Accuracy", xlabel="Models Name", title="Model Accuracy Graph")
ax.tick_params(axis='x', rotation = 10)

#show values on barplot
show_values(ax, "v", space=0)
fig = ax.get_figure()
fig.savefig('/content/drive/MyDrive/297_NLP/Final_Project/All_model_Accuracy_compare', dpi = 400)

# %%
# d = {
#     'x':    ['Q1', 'Q1', 'Q1', 'Q1', 
#              'Q2', 'Q2', 'Q2', 'Q2', 
#              'Q3', 'Q3', 'Q3', 'Q3'],
#     'y':    [ 98.87,    21.96,   95.61,     99.33,     
#              96.01,     81.66,    85.60,    92.57,  
#              57.64,  07.12,  02.61,  01.25],
#     'group':[  'deepset/roberta-base-squad2',  'albert-base-v2', 'deepset/tinyroberta-squad2',   'deepset/roberta-large-squad2',  
#              'deepset/roberta-base-squad2',  'albert-base-v2',   'deepset/tinyroberta-squad2',  'deepset/roberta-large-squad2',  
#              'deepset/roberta-base-squad2',  'albert-base-v2',  'deepset/tinyroberta-squad2','deepset/roberta-large-squad2']
# }

# %%
d = {
    'x':    ['Q1', 'Q1', 'Q1', 'Q1', 'Q1', 'Q1', 
             'Q2', 'Q2', 'Q2', 'Q2', 'Q2', 'Q2',
             'Q3', 'Q3', 'Q3', 'Q3', 'Q3', 'Q3'],
    'y':    [   98.80,    91.18,   89.03,  21.96,   95.61,    99.33,   
                91.18,    73.07,  85.54,  81.66,    85.60,    92.57, 
                94.38,    93.21,   90.84, 07.12,  02.61,  01.25],
    'group':[  'deepset/roberta-base-squad2',  'distilbert-base-cased-distilled-squad', 'deepset/minilm-uncased-squad2', 'albert-base-v2', 'deepset/tinyroberta-squad2',   'deepset/roberta-large-squad2',  
             'deepset/roberta-base-squad2',  'distilbert-base-cased-distilled-squad',  'deepset/minilm-uncased-squad2', 'albert-base-v2', 'deepset/tinyroberta-squad2',   'deepset/roberta-large-squad2',  
             'deepset/roberta-base-squad2',  'distilbert-base-cased-distilled-squad',  'deepset/minilm-uncased-squad2','albert-base-v2', 'deepset/tinyroberta-squad2',   'deepset/roberta-large-squad2',]
}

# sns.barplot(x='x', y='y', hue="group", data=d)


sns.set(rc={'figure.figsize':(20, 10)})
ax = sns.barplot(x='x', y='y', hue="group", data=d)
ax.set(ylabel="Percentage Accuracy", xlabel="Question Number", title="Model Accuracy on Questions Graph")
ax.tick_params(axis='x', rotation =30)

#show values on barplot
show_values(ax, "v", space=0)
fig = ax.get_figure()
fig.savefig('/content/drive/MyDrive/297_NLP/Final_Project/all_Question_Models_Accuracy_compare', dpi = 400)
